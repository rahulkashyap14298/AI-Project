# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulkashyap14298/about-us/blob/master/notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
urerySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));ls=Array.from(document.qu
# Out:
#   File "<ipython-input-1-686bc99fdc49>", line 1
#     urerySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
#                              ^
# SyntaxError: invalid syntax

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d92190a2-0a4d-487f-ad88-51828b04c746" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d92190a2-0a4d-487f-ad88-51828b04c746">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving url_fan.csv to url_fan.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ddb0678b-3289-45f4-964b-a1ecd847953a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ddb0678b-3289-45f4-964b-a1ecd847953a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving url_geyser.csv to url_geyser.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1b60b07c-a9e9-4c28-9e25-e35c24d7a92f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b60b07c-a9e9-4c28-9e25-e35c24d7a92f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving url_juicer.csv to url_juicer.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-50b779fc-d487-42da-931d-dd7291e4aa4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50b779fc-d487-42da-931d-dd7291e4aa4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving url_laptop.csv to url_laptop.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4b398830-7a9b-469a-b262-97f05c403edd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b398830-7a9b-469a-b262-97f05c403edd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving url_refrigerator.csv to url_refrigerator.csv

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.vision import *
from fastai.metrics import error_rate
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
img_counter=[]
img_counter.append(10)

# %%
folder = 'fan'
url_file = 'url_fan.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'geyser'
url_file = 'url_geyser.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'juicer'
url_file = 'url_juicer.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'laptop'
url_file = 'url_laptop.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
folder = 'refrigerator'
url_file = 'url_refrigerator.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(url_file, dest, max_pics=1000)

# %%
classes = ['fan','geyser','juicer','laptop','refrigerator']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# fan
# geyser
# juicer
# laptop
# refrigerator

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['fan', 'geyser', 'juicer', 'laptop', 'refrigerator']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
